# %%
a,b=1,2

# %%
start = [1,1]
iter = 15
for i in range(iter):
  start=[start[-1],sum(start)]
start[-1]
# Out:
# 1597

# %%
start = [1,1]
iter = 15
for i in range(iter):
  if  i == 11:
    break
  start=[start[-1],sum(start)]
start[-1]
# Out:
# 233

# %%
start = [1,1]
iter = 15
for i in range(iter):
  if  i == 11:
    continue
  start=[start[-1],sum(start)]
start[-1]
# Out:
# 987
